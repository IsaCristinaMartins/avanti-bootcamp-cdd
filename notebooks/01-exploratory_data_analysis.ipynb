# %% [markdown]
# # Análise exploratória de dados

# %%
### Import de bibliotecas para manipulação dos dados 
import pandas as pd
import numpy as np
import math

### para visualizacao 
import seaborn as sns
import matplotlib.pyplot as plt

### para obter estatisticas de teste
import scipy.stats as stats
from scipy.stats import norm

# %% [markdown]
# ## 1. Descrição dos dados

# %%
# Caminho do arquivo no projeto
pasta_arquivo = '/mnt/c/Users/Isabel/Documents/bootcamp_CDD/avanti-bootcamp-cdd/data/raw/diamonds.csv'

#Leitura do conjunto de dados 
df_diamonds = pd.read_csv(pasta_arquivo, delimiter=',')
df_diamonds.head(10)
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z
# 0   0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7   0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8   0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9   0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39

# %%
#Dicionário de dados

# %%
pasta_dicionario = '/mnt/c/Users/Isabel/Documents/bootcamp_CDD/avanti-bootcamp-cdd/data/external/Dicionário_de_dados - Página1.csv'
#Leitura do conjunto de dados 
dicionario = pd.read_csv(pasta_dicionario, delimiter=',')
dicionario.head(10)
#pd.set_option('display.max_colwidth', None)
# Out:
#   Dicionário dos dados    Unnamed: 1                      Unnamed: 2  \
# 0            Variável      Tradução                       Descrição
# 1                Carat  Quilate (ct)    Peso do diamante em quilates
# 2                  Cut         Corte              Qualidade do corte
# 3                Color           Cor                 Cor do diamante
# 4              Clarity       Clareza             Clareza do diamante
# 5                Depth  Profundidade        Profundidade do diamante
# 6                Table    Proporção       Proporção base  vs    topo
# 7                Price        Preço         Valor do diamante em USD
# 8                    X  Comprimento   Comprimento em milímetros (mm)
# 9                    Y       Largura       Largura em milímetros(mm)
#
#                                           Unnamed: 3            Unnamed: 4  \
# 0                                 Espectro de opções                 Tipo
# 1                                   0.2 ---- 5.01 ct   Quatitativo - Float
# 2              Fair, Good, Very Good, Premium, Ideal  Qualitativo - String
# 3                               D (best) - J (worst)  Qualitativa - string
# 4  1 (worst), SI2, SI1, VS2, VS1, VVS2, VVS1, IF ...  Qualitativo - String
# 5  Valor obtido pela equação ( percentual de prof...  Quantitativo - Float
# 6                                        43.0 - 95.0  Quantitativo - Float
# 7                                  $326 ---- $18,823  Quantitativo - Float
# 8                                        0--10.74 mm  Quantitativo - Float
# 9                                         0--58.9 mm  Quantitativo - Float
#
#   Unnamed: 5
# 0   Subtipo
# 1   Contínua
# 2    Ordinal
# 3   Ordinal
# 4    Ordinal
# 5   Contínua
# 6   Contínua
# 7  Discretas
# 8   Contínua
# 9   Contínua

# %%
#Análise do tipo das variáveis a serem analisadas
df_diamonds.info()

# %%
#Análise  das estatisticas descritiva geral do DF 
analise_quilates = df_diamonds['carat'].describe()
print(f'Análise estatística descritiva geral do quesito quilates:')
print(analise_quilates)

analise_profundidade = df_diamonds['depth'].describe()
print(f'Análise estatística descritiva geral do quesito profundidade:')
print(analise_profundidade)

analise_proporcao = df_diamonds['table'].describe()
print(f'Análise estatística descritiva geral do quesito proporção:')
print(analise_proporcao)

analise_preco = df_diamonds['price'].describe()
print(f'Análise estatística descritiva geral do quesito preço:')
print(analise_preco)

analise_comprimento = df_diamonds['x'].describe()
print(f'Análise estatística descritiva geral do quesito comprimento:')
print(analise_comprimento)

analise_largura = df_diamonds['y'].describe()
print(f'Análise estatística descritiva geral do quesito Largura:')
print(analise_largura)

analise_altura = df_diamonds['z'].describe()
print(f'Análise estatística descritiva geral do quesito altura:')
print(analise_altura)

# %% [markdown]
# ## 2. Perguntas de partida e hipóteses

# %% [markdown]
# ## 3. Insights
